# %%
print("hello world")
# Out:
# hello world

# %%
print("hello world ")

# %%
print("lets start")
# Out:
# lets start

# %%
print ("hello")
# Out:
# hello

# %%
print("hii")
# Out:
# hii

# %%
print("hello keeki")
# Out:
# hello keeki

# %%
a=1
b=2
print(a+b)
# Out:
# 3
