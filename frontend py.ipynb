# %%
pip install flask flask-cors pandas requests jsonify
# Out:
# Requirement already satisfied: flask in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (3.1.3)
# Requirement already satisfied: flask-cors in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (6.0.2)
# Requirement already satisfied: pandas in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (3.0.1)
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting jsonify
#   Using cached jsonify-0.5.tar.gz (1.0 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: blinker>=1.9.0 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from flask) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\nikita\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\nikita\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.3)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.6-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: colorama in c:\users\nikita\appdata\roaming\python\python313\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\nikita\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.6-cp313-cp313-win_amd64.whl (154 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Building wheels for collected packages: jsonify
#   Building wheel for jsonify (pyproject.toml): started
#   Building wheel for jsonify (pyproject.toml): finished with status 'done'
#   Created wheel for jsonify: filename=jsonify-0.5-py3-none-any.whl size=1571 sha256=c6bdcb76b8b1e44dfad8c8d54402f060fcca197fc003130efb7bd995f45c158b
#   Stored in directory: c:\users\nikita\appdata\local\pip\cache\wheels\b7\80\82\b150118b5d981cf749cdd387acfe132e611f1a2aafd739b437
# Successfully built jsonify
# Installing collected packages: jsonify, urllib3, idna, charset_normalizer, certifi, requests
#
#    ------ --------------------------------- 1/6 [urllib3]
#    ------ --------------------------------- 1/6 [urllib3]
#    ------------- -------------------------- 2/6 [idna]
#    --------------------------------- ------ 5/6 [requests]
#    ---------------------------------------- 6/6 [requests]
#
# Successfully installed certifi-2026.2.25 charset_normalizer-3.4.6 idna-3.11 jsonify-0.5 requests-2.32.5 urllib3-2.6.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\NIKITA\AppData\Local\Programs\Python\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from flask import Flask, request, jsonify
import pickle
import pandas as pd
from flask_cors import CORS # This allows your HTML to talk to this Python script

app = Flask(__name__)
CORS(app) # Vital for frontend-backend communication

# 1. Load the trained model (Ensure the .pkl file is in the same folder)
model = pickle.load(open('crop_price_model.pkl', 'rb'))

# 2. Define the API route
@app.route('/predict', methods=['POST'])
def predict():
    # Get data sent from the HTML frontend
    data = request.get_json()
    
    # Extract values
    state = data['state']
    district = data['district']
    commodity = data['commodity']
    
    # Transform data into the format your model expects (Dataframe)
    # Note: Your developer will need to handle LabelEncoding for text here
    input_data = pd.DataFrame([[state, district, commodity]], 
                              columns=['State', 'District', 'Commodity'])
    
    # 3. Make Prediction
    prediction = model.predict(input_data)
    
    # 4. Send the result back to the Frontend as JSON
    return jsonify({
        'min_price': round(prediction[0][0], 2),
        'max_price': round(prediction[0][1], 2),
        'modal_price': round(prediction[0][2], 2)
    })

if __name__ == '__main__':
    app.run(debug=True, port=5000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 10
#       7 CORS(app) # Vital for frontend-backend communication
#       9 # 1. Load the trained model (Ensure the .pkl file is in the same folder)
# ---> 10 model = pickle.load(open('crop_price_model.pkl', 'rb'))
#      12 # 2. Define the API route
#      13 @app.route('/predict', methods=['POST'])
#      14 def predict():
#      15     # Get data sent from the HTML frontend
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'crop_price_model.pkl'
